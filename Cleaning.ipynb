# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data["director"].fillna("Unknown", inplace=True)

# %%
data["cast"].fillna("Not Available", inplace=True)

# %%
data["country"].fillna(data["country"].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
data['date_added'] = data['date_added'].fillna(
    data['release_year'].astype(str) + '-01-01'
)

data['date_added'] = pd.to_datetime(data['date_added'], format='mixed')

# %%
data["year_added"] = data["date_added"].dt.year
data["month_added"] = data["date_added"].dt.month

# %%
data['date_added'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['rating'].mode()
# Out:
# 0    TV-MA
# Name: rating, dtype: object

# %%
data['rating'].fillna(data['rating'].mode()[0], inplace=True)

# %%
data['duration_num'] = data['duration'].str.extract('(\d+)')

# %%
data['duration_num'] = pd.to_numeric(data['duration_num'])

# %%
data['duration_num'].fillna(data['duration_num'].median(), inplace=True)

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# duration_num    0
# dtype: int64

# %%
data['duration_type'] = data['duration'].str.extract('([A-Za-z]+)')
data['duration_type'].fillna("min", inplace=True)

# %%
data.drop("duration", axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'listed_in', 'description', 'duration_num',
#        'duration_type'],
#       dtype='object')

# %%
data["main_genre"] = data["listed_in"].str.split(",").str[0]

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Feature Enginering
data["movie_duration_min"] = np.where(data["duration_type"]=="min", data["duration_num"], np.nan)

# %%
data["tv_seasons"] = np.where(data["duration_type"]=="Season", data["duration_num"], np.nan)

# %%
data["content_age"] = data["year_added"] - data["release_year"]

# %%
data["country_count"] = data["country"].str.count(",") + 1

# %%
data["cast_count"] = data["cast"].apply(lambda x: 0 if x=="Not Available" else len(x.split(",")))

# %%
data["director_known"] = np.where(data["director"]=="Unknown", 0, 1)

# %%
data["is_movie"] = np.where(data["type"]=="Movie",1,0)

# %% [markdown]
# statstical analysis

# %%
data.describe()
# Out:
#                           date_added  release_year  duration_num   year_added  \
# count                           8807   8807.000000   8807.000000  8807.000000
# mean   2019-05-13 21:37:54.781423872   2014.180198     69.853071  2018.863291
# min              2003-01-01 00:00:00   1925.000000      1.000000  2003.000000
# 25%              2018-04-03 00:00:00   2013.000000      2.000000  2018.000000
# 50%              2019-07-01 00:00:00   2017.000000     88.000000  2019.000000
# 75%              2020-08-18 00:00:00   2019.000000    106.000000  2020.000000
# max              2021-09-25 00:00:00   2021.000000    312.000000  2021.000000
# std                              NaN      8.819312     50.807276     1.602696
#
#        month_added  movie_duration_min  tv_seasons  content_age  \
# count  8807.000000         6131.000000      1793.0  8807.000000
# mean      6.648575           99.571522         1.0     4.683093
# min       1.000000            3.000000         1.0    -3.000000
# 25%       4.000000           87.000000         1.0     0.000000
# 50%       7.000000           98.000000         1.0     1.000000
# 75%      10.000000          114.000000         1.0     5.000000
# max      12.000000          312.000000         1.0    93.000000
# std       3.439879           28.284829         0.0     8.783427
#
#        country_count   cast_count  director_known     is_movie
# count    8807.000000  8807.000000     8807.000000  8807.000000
# mean        1.231975     7.281254        0.700920     0.696151
# min         1.000000     0.000000        0.000000     0.000000
# 25%         1.000000     4.000000        0.000000     0.000000
# 50%         1.000000     8.000000        1.000000     1.000000
# 75%         1.000000    10.000000        1.000000     1.000000
# max        12.000000    50.000000        1.000000     1.000000
# std         0.668818     4.862244        0.457881     0.459944

# %% [markdown]
# EDA

# %%
data["year_added"].value_counts().sort_index()
# Out:
# year_added
# 2003       2
# 2008       3
# 2009       2
# 2010       2
# 2011      13
# 2012       4
# 2013      12
# 2014      24
# 2015      84
# 2016     430
# 2017    1188
# 2018    1650
# 2019    2016
# 2020    1879
# 2021    1498
# Name: count, dtype: int64

# %%
data["year_added"].value_counts().sort_index().plot(kind="line", marker="o")
plt.title("Content Added Over Years")
plt.xlabel("Year")
plt.ylabel("Number of Shows")
plt.show()

# %% [markdown]
# Insights: Netflix growth trend

# %%
data["country"].value_counts().head(10)
# Out:
# country
# United States     3649
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
data["country"].value_counts().head(10).plot(kind="barh")
plt.title("Top 10 Countries on Netflix")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Which country dominates Netflix 🌍
# netflix

# %%
data["rating"].value_counts().plot(kind="bar")
plt.title("Ratings Distribution")
plt.show()

# %% [markdown]
# Is Netflix family-friendly or adult-focused?
# adult fouced

# %%
data["main_genre"].value_counts().head(10).plot(kind="bar")
plt.title("Top Genres on Netflix")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Which genre Netflix loves most : comadies and dramas

# %%
data["movie_duration_min"].describe()
# Out:
# count    6131.000000
# mean       99.571522
# std        28.284829
# min         3.000000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: movie_duration_min, dtype: float64

# %%
data["movie_duration_min"].dropna().plot(kind="hist", bins=20)
plt.title("Movie Duration Distribution")
plt.show()

# %%
data["tv_seasons"].describe()
# Out:
# count    1793.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: tv_seasons, dtype: float64

# %%
data["tv_seasons"].dropna().plot(kind="hist", bins=10)
plt.title("TV Seasons Distribution")
plt.show()

# %%
pd.crosstab(data["year_added"], data["type"]).plot(kind="line", marker="o")
plt.title("Movies vs TV Shows Growth Over Time")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Netflix shifting from Movies → TV Shows?

# %%
pd.crosstab(data["country"], data["type"]).head(10).plot(kind="bar", stacked=True)
plt.title("Country vs Type")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Which country makes more movies vs shows?

# %%
pd.crosstab(data["rating"], data["type"]).plot(kind="bar", stacked=True)
plt.title("Ratings vs Type")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Are TV shows more adult (TV-MA)?

# %%
data["month_added"].value_counts().sort_index().plot(kind="bar")
plt.title("Content Added by Month")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Which months Netflix releases most content

# %%
data.groupby("year_added")["movie_duration_min"].mean().plot(marker="o")
plt.title("Average Movie Duration by Year")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Movies getting longer or shorter?

# %%
import seaborn as sns

corr = data.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 👉 Insight:
#
# Relationship between engineered features

# %% [markdown]
# OUTLIERS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.boxplot(data=data[["movie_duration_min","tv_seasons","content_age","cast_count"]])
plt.title("Outlier Detection Boxplot")
plt.show()

# %%
def detect_outliers(col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    outliers = data[(data[col] < lower) | (data[col] > upper)]
    
    print(col, "outliers count:", len(outliers))

# %%
for col in ["movie_duration_min","tv_seasons","content_age","cast_count"]:
    detect_outliers(col)
# Out:
# movie_duration_min outliers count: 450
# tv_seasons outliers count: 0
# content_age outliers count: 972
# cast_count outliers count: 123

# %%
def cap_outliers(col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    data[col] = np.where(data[col] > upper, upper, data[col])
    data[col] = np.where(data[col] < lower, lower, data[col])

# %%
for col in ["movie_duration_min","tv_seasons","content_age","cast_count"]:
    cap_outliers(col)

# %%
for col in ["movie_duration_min","tv_seasons","content_age","cast_count"]:
    detect_outliers(col)
# Out:
# movie_duration_min outliers count: 0
# tv_seasons outliers count: 0
# content_age outliers count: 0
# cast_count outliers count: 0

# %%
data.describe()
# Out:
#                           date_added  release_year  duration_num   year_added  \
# count                           8807   8807.000000   8807.000000  8807.000000
# mean   2019-05-13 21:37:54.781423872   2014.180198     69.853071  2018.863291
# min              2003-01-01 00:00:00   1925.000000      1.000000  2003.000000
# 25%              2018-04-03 00:00:00   2013.000000      2.000000  2018.000000
# 50%              2019-07-01 00:00:00   2017.000000     88.000000  2019.000000
# 75%              2020-08-18 00:00:00   2019.000000    106.000000  2020.000000
# max              2021-09-25 00:00:00   2021.000000    312.000000  2021.000000
# std                              NaN      8.819312     50.807276     1.602696
#
#        month_added  movie_duration_min  tv_seasons  content_age  \
# count  8807.000000         6131.000000      1793.0  8807.000000
# mean      6.648575           99.573316         1.0     3.309527
# min       1.000000           46.500000         1.0    -3.000000
# 25%       4.000000           87.000000         1.0     0.000000
# 50%       7.000000           98.000000         1.0     1.000000
# 75%      10.000000          114.000000         1.0     5.000000
# max      12.000000          154.500000         1.0    12.500000
# std       3.439879           25.012497         0.0     4.311845
#
#        country_count   cast_count  director_known     is_movie
# count    8807.000000  8807.000000     8807.000000  8807.000000
# mean        1.231975     7.180084        0.700920     0.696151
# min         1.000000     0.000000        0.000000     0.000000
# 25%         1.000000     4.000000        0.000000     0.000000
# 50%         1.000000     8.000000        1.000000     1.000000
# 75%         1.000000    10.000000        1.000000     1.000000
# max        12.000000    19.000000        1.000000     1.000000
# std         0.668818     4.444351        0.457881     0.459944

# %%
data["movie_duration_min"].describe()
# Out:
# count    6131.000000
# mean       99.573316
# std        25.012497
# min        46.500000
# 25%        87.000000
# 50%        98.000000
# 75%       114.000000
# max       154.500000
# Name: movie_duration_min, dtype: float64

# %%
data["movie_duration_min"].mean()
data["movie_duration_min"].median()
data["movie_duration_min"].std()
# Out:
# np.float64(25.0124970216343)

# %%
data["tv_seasons"].describe()
# Out:
# count    1793.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: tv_seasons, dtype: float64

# %%
data["content_age"].describe()
# Out:
# count    8807.000000
# mean        3.309527
# std         4.311845
# min        -3.000000
# 25%         0.000000
# 50%         1.000000
# 75%         5.000000
# max        12.500000
# Name: content_age, dtype: float64

# %%
data["content_age"].mean()
# Out:
# np.float64(3.309526513001022)

# %%
data["cast_count"].describe()
# Out:
# count    8807.000000
# mean        7.180084
# std         4.444351
# min         0.000000
# 25%         4.000000
# 50%         8.000000
# 75%        10.000000
# max        19.000000
# Name: cast_count, dtype: float64

# %%
data.groupby("type")[["movie_duration_min","tv_seasons","content_age"]].mean()
# Out:
#          movie_duration_min  tv_seasons  content_age
# type
# Movie             99.573316         NaN     3.917469
# TV Show                 NaN         1.0     1.916667

# %%
data.corr(numeric_only=True)
# Out:
#                     release_year  duration_num  year_added  month_added  \
# release_year            1.000000     -0.249174    0.113208    -0.038500
# duration_num           -0.249174      1.000000    0.035283    -0.014886
# year_added              0.113208      0.035283    1.000000    -0.148432
# month_added            -0.038500     -0.014886   -0.148432     1.000000
# movie_duration_min     -0.192870      0.978838    0.131045     0.008051
# tv_seasons                   NaN           NaN         NaN          NaN
# content_age            -0.802222      0.302591    0.102838    -0.020749
# country_count          -0.037833      0.108597   -0.015648    -0.015501
# cast_count             -0.110128      0.136841    0.128687     0.002461
# director_known         -0.173518      0.814722    0.006485    -0.017207
# is_movie               -0.181710      0.885416   -0.013223    -0.017830
#
#                     movie_duration_min  tv_seasons  content_age  \
# release_year                 -0.192870         NaN    -0.802222
# duration_num                  0.978838         NaN     0.302591
# year_added                    0.131045         NaN     0.102838
# month_added                   0.008051         NaN    -0.020749
# movie_duration_min            1.000000         NaN     0.271435
# tv_seasons                         NaN         NaN          NaN
# content_age                   0.271435         NaN     1.000000
# country_count                 0.052117         NaN     0.074291
# cast_count                    0.376063         NaN     0.204460
# director_known                0.201078         NaN     0.208003
# is_movie                           NaN         NaN     0.213426
#
#                     country_count  cast_count  director_known  is_movie
# release_year            -0.037833   -0.110128       -0.173518 -0.181710
# duration_num             0.108597    0.136841        0.814722  0.885416
# year_added              -0.015648    0.128687        0.006485 -0.013223
# month_added             -0.015501    0.002461       -0.017207 -0.017830
# movie_duration_min       0.052117    0.376063        0.201078       NaN
# tv_seasons                    NaN         NaN             NaN       NaN
# content_age              0.074291    0.204460        0.208003  0.213426
# country_count            1.000000    0.066974        0.101983  0.098108
# cast_count               0.066974    1.000000        0.048177  0.010105
# director_known           0.101983    0.048177        1.000000  0.887368
# is_movie                 0.098108    0.010105        0.887368  1.000000

# %%
import seaborn as sns
sns.heatmap(data.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Q1 — Does Netflix prefer recent content?

# %%
data["content_age"].mean()
# Out:
# np.float64(3.309526513001022)

# %% [markdown]
# Q2 — Movie vs TV Show ratio

# %%
data["type"].value_counts(normalize=True)*100
# Out:
# type
# Movie      69.615079
# TV Show    30.384921
# Name: proportion, dtype: float64

# %% [markdown]
# Q3 — Which year added most content?

# %%
data["year_added"].mode()
# Out:
# 0    2019
# Name: year_added, dtype: int32

# %%
data.to_csv("netflix_cleaned_final.csv", index=False)
